# %% [markdown]
# # Real World Evidence

# %% [markdown]
# # Installation to start analysis
# * Normally: Download and install python and key packages
#     - Go to: https://www.continuum.io/downloads
#     - Select Anaconda (for your operating system), download and install
#     - After installations, select and start "Jupyter notebook"
# * Today: We have installed everything (python, packages, data) on a USB
#     - Navigate to the USB folder, click "jupyter notebook"

# %% [markdown]
# # Key instructions for using the notebook
#
# * A notebook combines text, code and results
# * Use instructions
#     - Type code or text in a cell
#     - Press SHIFT+ENTER to execute the code in the cell
#     - Press TAB to see the methods (commands) available to use on an object
#     - Press SHIFT+TAB to get help about a method
# * Code instructions
#     - Standard python language to write code
#         - Example: Type "Print('Hello World')"
#         - Example: Type "2 + 2"
#     - Can be extended by importing packages
#         - Example 1: Type "import pandas as pd"
#             - A package to analyse data

# %%
print('Hello World!')
# Out:
# Hello World!

# %%
2+2
# Out:
# 4

# %%
names = ['Ann', 'Jim', 'John']
for name in names:
    print(name)
# Out:
# Ann
# Jim
# John

# %% [markdown]
# # Example: Rota virus
#
# * Did the introduction of vaccinations against the rota virus in 2005 and 2015 reduce the number of rota cases?
#
# * Data from the national patient registry
#
# * Simulate individual data
# * Provide real aggregate data

# %%
#import key packages needed to do the analysis
import pandas as pd
import numpy as np
import seaborn as sns

# %%
# %matplotlib inline

# %%
df = pd.DataFrame()

# %%
df['pid'] = np.random.randint(1,10000,10000)
df['age'] = np.random.randint(0,6,10000)
df['month'] = np.random.randint(1,12,10000)
df['year'] = np.random.randint(2000,2017,10000)

# %%
df.head()
# Out:
#     pid  age  month  year
# 0  7495    3      4  2012
# 1  8308    2      4  2013
# 2  9117    4      9  2002
# 3  7331    5     11  2016
# 4  7046    3      5  2004

# %%
# aggregate to month and year
events = df.groupby(['year', 'month']).size()
events.head()
# Out:
# year  month
# 2000  1        50
#       2        51
#       3        57
#       4        59
#       5        39
# dtype: int64

# %%
events.plot.line()

# %%
#one line for each month
events.unstack()
events.unstack().plot()

# %%
# Get data aggregate data on rotavirus
path="C:/Users/hmelberg_adm/Google Drive/rota/"
file="rota_cases_a08x_alle_ages.xlsx"
df = pd.read_excel(file)

# %%
df.head()
# Out:
#    year  month  cases_a08x_alle_ages
# 0  2000      1                   259
# 1  2000      2                   273
# 2  2000      3                   366
# 3  2000      4                   392
# 4  2000      5                   250

# %%
df.columns
# Out:
# Index(['year', 'month', 'cases_a08x_alle_ages'], dtype='object')

# %%
df.columns = ['year', 'month', 'events']

# %%
df.head()
# Out:
#    year  month  events
# 0  2000      1     259
# 1  2000      2     273
# 2  2000      3     366
# 3  2000      4     392
# 4  2000      5     250

# %%
df.events.plot()

# %%
df = df.set_index(['year', 'month'])

# %%
df.head()
# Out:
#             events
# year month
# 2000 1         259
#      2         273
#      3         366
#      4         392
#      5         250

# %%
df.plot()

# %%
df.unstack('year').plot()
